# %% [markdown]
# <a href="https://colab.research.google.com/github/hanifnurf/TKC_Covid19/blob/main/deteksi_covid_19_images_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Detecting Covid-19 Images
#
# <br>
#
# This project We will build Deep learning system for Detection Covid-19 in X-rays images.
#
# With the intensive increase in ICU beds, the demand for immediate exam results is more likely than in this pandemic,The goal is to create a Deep learning system that can identify X-ray images and classify the patient as Normal or if they have Covid-19.
#
#
# <br>
#
#
#
# #### <b>WARNING</b>: This project was developed by a Machine learning engineer with technical knowledge in Deep learning, I also emphasize that I made this system for technical and intuitive demonstration of a Deep learning application in the Computer Vision area, which it does not qualify as a job of scientific rigor because it would need a business specialist in this case a doctor or health professional to collaborate on a solution that fits scientific standards.
#
#
# <br>
# <br>
#
# <p align=center>
# <img src="https://miro.medium.com/max/3840/1*6TPePg_wW6MZ7rkwFVJGyw.png" width="80%"></p>
#
#
#
#
# <br>
# <br>
# <hr>

# %% [markdown]
# <br>
#
#
# ### 1. Frameworks
#
# <br>

# %%
# !kaggle datasets download -d nabeelsajid917/covid-19-x-ray-10000-images
api_token = {"username":"hanifnurfauzi","key":"ee0b8c9181ca9ea8c7696d48a41280a9"}
import json
import zipfile
import os
with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# Downloading covid-19-x-ray-10000-images.zip to /content
#  97% 90.0M/92.7M [00:01<00:00, 91.0MB/s]
# 100% 92.7M/92.7M [00:01<00:00, 74.1MB/s]

# %%
# !unzip "/content/covid-19-x-ray-10000-images.zip" -d "/content/" # ekstraksi .zip

# %%
import numpy as np
import pandas as pd 
import os 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import seaborn as sns 

# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')


from PIL import Image 
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import glob
import time 



# seed 
tf.random.set_seed(42)
np.random.seed(42)

# %%
# dataset
dataset = '/content/dataset'

# %%
# spliting images 
normal_images = []

for img_path in glob.glob(dataset + '/normal/*'):
  normal_images.append(mpimg.imread(img_path))



plt.figure(figsize=(10,5))


plt.subplot(1,2,1)
plt.title('Normal')
plt.imshow(normal_images[0], cmap='gray')




covid_images = []

for img_path in glob.glob(dataset + '/covid/*'):
  covid_images.append(mpimg.imread(img_path))

plt.subplot(1,2,2)
plt.title('Covid-19')
plt.imshow(covid_images[0], cmap='gray')
plt.tight_layout()

# %%
# size of class images  
print('Normal: ', len(normal_images))
print('Covid: ', len(covid_images))
# Out:
# Normal:  28
# Covid:  70

# %%
# define shape 
image_height = 150
image_width = 150
channels = 3 


# parameters 
input_shape = (image_height, image_width, channels)
number_classe = 2 
batch_size = 6
epochs = 40
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
plt.imshow(normal_images[10], cmap='gray')
plt.title('Normal')
# Out:
# Text(0.5, 1.0, 'Normal')

# %%
plt.imshow(normal_images[7], cmap='hot')
plt.axis('off')
plt.colorbar()

# %% [markdown]
# <hr>
# <br>
# <br>
#
#
# ### 2. Data Augmentation
#
#
# Data Augmentation encompasses a suite of techniques that enhance the size and quality of training datasets such that better Deep Learning models can be built using them. The image augmentation algorithms discussed in this survey include geometric transformations, color space augmentations, kernel filters, mixing images, random erasing, feature space augmentation.
#
#
#
# <br>

# %%
# Data Augmentation 
data_generator = ImageDataGenerator(featurewise_center=False,
                                    featurewise_std_normalization=False,
                                    rotation_range=10,
                                    zoom_range=0.10,
                                    rescale = 1./255,
                                    validation_split=0.30)


# Train 
train_generator = data_generator.flow_from_directory(dataset,
                                                     target_size=(image_height, image_width),
                                                     batch_size=batch_size,
                                                     class_mode='binary',
                                                     subset='training')


# Validation 
validation_generator = data_generator.flow_from_directory(dataset,
                                                     target_size=(image_height, image_width),
                                                     batch_size=batch_size,
                                                     class_mode='binary',
                                                     shuffle=False,
                                                     subset='validation')
# Out:
# Found 69 images belonging to 2 classes.
# Found 29 images belonging to 2 classes.

# %% [markdown]
# <br>
# <br>
#
#
# ### 3. Convolutional Neural Network
#
# I decided choose for Convolutional Neural Networks, who are one  architecture who have best performance results when works on images.Beyond consistent and default in problems of images classification.
#
#
# I will explain a little about the architecture that I set up and explain the use of the main layers of the network and why I chose to use it.
#
#
# #### <b> Architecture </b>
#
#
# * Input layer is responsible for receiving images (150x150x3)
# * Conv2D with 32 filters, kernel_size=(3,3) and padding='same'
# * MaxPool2D with pool_size=(2,2)
# * <b> LayerNormalization </b> This is one technique of normalization, substitute the BatchNormalization, in addition to being faster in calculating gradients and optimizing, it gets good results with it its specificity is pixel normalization done by channel and not by mini-batch.
# * Conv2D with 64 filters, kernel_size=(3,3) and padding='same'
# * MaxPool2D with pool_size=(2,2)
# * <b> SpartialDropout2D </b> This layer was necessary for control Overfitting, by terms little images, the risk of overfitting it was biggest, SpartialDropout2D is one variant of dropout, but Spartial is very better for Feature maps, because he drops pixels after MaxPooling.
# * Conv2D with 128 filters, kernel_size=(3,3) and padding='same'
# * MaxPool2D with pool_size=(2,2)
# * LayerNormalization again other normalization
# * Conv2D with 256 filters, kernel_size=(3,3) and padding='same'
# * MaxPool2D with pool_size=(2,2)
# * SpartialDropout2D again other dropout
# * Conv2D with 512 filters, kernel_size=(3,3) and padding='same'
# * MaxPool2D with pool_size=(2,2)
# * LayerNormalization again other normalization
# * <b> GlobalMaxPool2D </b> I used layer GlobalMaxPool for decrease a number of parameters of network, different of Flatten this layer reduce Feature maps in Global scale, making a summary by channel of images, very good layer.
# * Dense layer with 128 neurons and relu activation
# * Dense layer again for the output layer in architecture
#
#
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
#
#
# #### LayerNormalization
#
# Link for studies abourt LayerNormalization: https://www.google.com/url?sa=i&url=https%3A%2F%2Ftowardsdatascience.com%2Fdifferent-types-of-normalization-in-tensorflow-dac60396efb0&psig=AOvVaw3K-OwOMngUODmIosDMWdsk&ust=1596501817145000&source=images&cd=vfe&ved=0CA0QjhxqFwoTCMCIwPHm_eoCFQAAAAAdAAAAABAD
#
# <br>
#
#
# #### GlobalMaxPool2D
#
#
# References for studies: https://www.google.com/url?sa=i&url=https%3A%2F%2Fpeltarion.com%2Fknowledge-center%2Fdocumentation%2Fmodeling-view%2Fbuild-an-ai-model%2Fblocks%2F2d-global-max-pooling&psig=AOvVaw1Vgi5x1VUzND0QBdBDu9Qy&ust=1596501451109000&source=images&cd=vfe&ved=2ahUKEwi0n6TA5f3qAhXyMLkGHYsSDdIQr4kDegUIARCRAQ
#
# <br>
#
# <p align=center>
# <img src="https://alexisbcook.github.io/assets/global_average_pooling.png" width="50%"></p>
#
#
#
#
# <br>
# <br>

# %% [markdown]
# **MODEL PERTAMA**

# %%
# Convolutional Neural Network 

model1 = tf.keras.Sequential([tf.keras.layers.InputLayer(input_shape=input_shape),
                                    tf.keras.layers.Conv2D(32, (3,3), (1,1), padding='same', activation='relu'),
                                    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                                    tf.keras.layers.LayerNormalization(axis=-1),
                                    tf.keras.layers.Conv2D(64, (3,3), (1,1), padding='same', activation='relu'),                                   
                                    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                                    tf.keras.layers.SpatialDropout2D(0.20),
                                    tf.keras.layers.Conv2D(128, (3,3), (1,1), padding='same', activation='relu'),                                   
                                    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                                    tf.keras.layers.LayerNormalization(axis=-1),
                                    tf.keras.layers.Conv2D(256, (3,3), (1,1), padding='same', activation='relu'),                                   
                                    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                                    tf.keras.layers.SpatialDropout2D(0.20),                                  
                                    tf.keras.layers.Conv2D(512, (3,3), (1,1), padding='same', activation='relu'),
                                    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
                                    tf.keras.layers.LayerNormalization(axis=-1),
                                    tf.keras.layers.GlobalMaxPool2D(),
                                    tf.keras.layers.Dense(units=128, activation='relu'),
                                    tf.keras.layers.Dense(units=1, activation='sigmoid')
                                    ])


model1.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 150, 150, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  layer_normalization_3 (Laye  (None, 75, 75, 32)       64
#  rNormalization)
#
#  conv2d_11 (Conv2D)          (None, 75, 75, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  spatial_dropout2d_2 (Spatia  (None, 37, 37, 64)       0
#  lDropout2D)
#
#  conv2d_12 (Conv2D)          (None, 37, 37, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  layer_normalization_4 (Laye  (None, 18, 18, 128)      256
#  rNormalization)
#
#  conv2d_13 (Conv2D)          (None, 18, 18, 256)       295168
#
#  max_pooling2d_11 (MaxPoolin  (None, 9, 9, 256)        0
#  g2D)
#
#  spatial_dropout2d_3 (Spatia  (None, 9, 9, 256)        0
#  lDropout2D)
#
#  conv2d_14 (Conv2D)          (None, 9, 9, 512)         1180160
#
#  max_pooling2d_12 (MaxPoolin  (None, 4, 4, 512)        0
#  g2D)
#
#  layer_normalization_5 (Laye  (None, 4, 4, 512)        1024
#  rNormalization)
#
#  global_max_pooling2d_1 (Glo  (None, 512)              0
#  balMaxPooling2D)
#
#  dense_7 (Dense)             (None, 128)               65664
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,635,713
# Trainable params: 1,635,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
# CNN 
history1 = model1.fit(train_generator, validation_data=validation_generator, epochs=epochs)
# Out:
# Epoch 1/40
# 12/12 [==============================] - 4s 374ms/step - loss: 0.2009 - accuracy: 0.9130 - val_loss: 0.1311 - val_accuracy: 0.9655
# Epoch 2/40
# 12/12 [==============================] - 4s 342ms/step - loss: 0.1607 - accuracy: 0.9130 - val_loss: 0.6175 - val_accuracy: 0.8276
# Epoch 3/40
# 12/12 [==============================] - 4s 340ms/step - loss: 0.1993 - accuracy: 0.9130 - val_loss: 0.2704 - val_accuracy: 0.8276
# Epoch 4/40
# 12/12 [==============================] - 4s 339ms/step - loss: 0.2232 - accuracy: 0.9130 - val_loss: 0.2383 - val_accuracy: 0.8621
# Epoch 5/40
# 12/12 [==============================] - 4s 327ms/step - loss: 0.1831 - accuracy: 0.9420 - val_loss: 0.3406 - val_accuracy: 0.8621
# Epoch 6/40
# 12/12 [==============================] - 4s 336ms/step - loss: 0.1535 - accuracy: 0.9420 - val_loss: 0.1901 - val_accuracy: 0.9310
# Epoch 7/40
# 12/12 [==============================] - 4s 330ms/step - loss: 0.1095 - accuracy: 0.9565 - val_loss: 0.1547 - val_accuracy: 0.8966
# Epoch 8/40
# 12/12 [==============================] - 4s 342ms/step - loss: 0.1592 - accuracy: 0.9275 - val_loss: 0.1826 - val_accuracy: 0.8621
# Epoch 9/40
# 12/12 [==============================] - 4s 337ms/step - loss: 0.1097 - accuracy: 0.9855 - val_loss: 0.3574 - val_accuracy: 0.9310
# Epoch 30/40
# 12/12 [==============================] - 4s 331ms/step - loss: 0.0716 - accuracy: 0.9710 - val_loss: 0.2892 - val_accuracy: 0.8966
# Epoch 31/40
# 12/12 [==============================] - 4s 333ms/step - loss: 0.1669 - accuracy: 0.9420 - val_loss: 0.2745 - val_accuracy: 0.8966
# Epoch 32/40
# 12/12 [==============================] - 4s 344ms/step - loss: 0.0990 - accuracy: 0.9710 - val_loss: 0.4474 - val_accuracy: 0.8621
# Epoch 33/40
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0453 - accuracy: 0.9855 - val_loss: 0.3199 - val_accuracy: 0.8966
# Epoch 34/40
# 12/12 [==============================] - 4s 336ms/step - loss: 0.1504 - accuracy: 0.9565 - val_loss: 0.7258 - val_accuracy: 0.8276
# Epoch 35/40
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0743 - accuracy: 0.9710 - val_loss: 0.3532 - val_accuracy: 0.8276
# Epoch 36/40
# 12/12 [==============================] - 4s 342ms/step - loss: 0.0678 - accuracy: 0.9855 - val_loss: 0.2184 - val_accuracy: 0.8966
# Epoch 37/40
# 12/12 [==============================] - 4s 322ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.4357 - val_accuracy: 0.8276
# Epoch 38/40
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.4338 - val_accuracy: 0.8621
# Epoch 39/40
# 12/12 [==============================] - 4s 342ms/step - loss: 0.0546 - accuracy: 0.9855 - val_loss: 0.2205 - val_accuracy: 0.9310
# Epoch 40/40
# 12/12 [==============================] - 4s 338ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 0.8966

# %% [markdown]
# **MODEL KEDUA**

# %%
model2 = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(input_shape)),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
     tf.keras.layers.Dense(128,activation='relu'),
    #tf.keras.layers.Dropout(0.25)
    tf.keras.layers.Dense(1,activation='sigmoid')        
])

model2.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 148, 148, 32)      896
#
#  conv2d_6 (Conv2D)           (None, 146, 146, 64)      18496
#
#  max_pooling2d_5 (MaxPooling  (None, 73, 73, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 71, 71, 128)       73856
#
#  conv2d_8 (Conv2D)           (None, 69, 69, 256)       295168
#
#  max_pooling2d_6 (MaxPooling  (None, 34, 34, 256)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 16, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_2 (Dense)             (None, 512)               33554944
#
#  dense_3 (Dense)             (None, 128)               65664
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 34,599,233
# Trainable params: 34,599,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
# CNN 
history2 = model2.fit(train_generator, validation_data=validation_generator, epochs=epochs)
# Out:
# Epoch 1/40
# 12/12 [==============================] - 5s 389ms/step - loss: 0.6047 - accuracy: 0.7101 - val_loss: 0.5892 - val_accuracy: 0.7241
# Epoch 2/40
# 12/12 [==============================] - 4s 348ms/step - loss: 0.6099 - accuracy: 0.7101 - val_loss: 0.5929 - val_accuracy: 0.7241
# Epoch 3/40
# 12/12 [==============================] - 4s 367ms/step - loss: 0.6114 - accuracy: 0.7101 - val_loss: 0.5890 - val_accuracy: 0.7241
# Epoch 4/40
# 12/12 [==============================] - 4s 363ms/step - loss: 0.6058 - accuracy: 0.7101 - val_loss: 0.5940 - val_accuracy: 0.7241
# Epoch 5/40
# Epoch 26/40
# 12/12 [==============================] - 4s 351ms/step - loss: 0.6106 - accuracy: 0.7101 - val_loss: 0.5922 - val_accuracy: 0.7241
# Epoch 27/40
# 12/12 [==============================] - 4s 362ms/step - loss: 0.6020 - accuracy: 0.7101 - val_loss: 0.5892 - val_accuracy: 0.7241
# Epoch 28/40
# 12/12 [==============================] - 4s 358ms/step - loss: 0.6082 - accuracy: 0.7101 - val_loss: 0.5899 - val_accuracy: 0.7241
# Epoch 29/40
# 12/12 [==============================] - 4s 365ms/step - loss: 0.6148 - accuracy: 0.7101 - val_loss: 0.5923 - val_accuracy: 0.7241
# Epoch 30/40
# 12/12 [==============================] - 4s 366ms/step - loss: 0.6029 - accuracy: 0.7101 - val_loss: 0.5909 - val_accuracy: 0.7241
# Epoch 31/40
# 12/12 [==============================] - 4s 351ms/step - loss: 0.6052 - accuracy: 0.7101 - val_loss: 0.5893 - val_accuracy: 0.7241
# Epoch 32/40
# 12/12 [==============================] - 4s 356ms/step - loss: 0.6058 - accuracy: 0.7101 - val_loss: 0.5908 - val_accuracy: 0.7241
# Epoch 33/40
# 12/12 [==============================] - 4s 351ms/step - loss: 0.6049 - accuracy: 0.7101 - val_loss: 0.5894 - val_accuracy: 0.7241
# Epoch 34/40
# 12/12 [==============================] - 4s 347ms/step - loss: 0.6069 - accuracy: 0.7101 - val_loss: 0.5891 - val_accuracy: 0.7241
# Epoch 35/40
# 12/12 [==============================] - 4s 351ms/step - loss: 0.6156 - accuracy: 0.7101 - val_loss: 0.5920 - val_accuracy: 0.7241
# Epoch 36/40
# 12/12 [==============================] - 4s 350ms/step - loss: 0.6070 - accuracy: 0.7101 - val_loss: 0.5913 - val_accuracy: 0.7241
# Epoch 37/40
# 12/12 [==============================] - 4s 358ms/step - loss: 0.6042 - accuracy: 0.7101 - val_loss: 0.5899 - val_accuracy: 0.7241
# Epoch 38/40
# 12/12 [==============================] - 4s 351ms/step - loss: 0.6045 - accuracy: 0.7101 - val_loss: 0.5903 - val_accuracy: 0.7241
# Epoch 39/40
# 12/12 [==============================] - 4s 367ms/step - loss: 0.6040 - accuracy: 0.7101 - val_loss: 0.5912 - val_accuracy: 0.7241
# Epoch 40/40
# 12/12 [==============================] - 4s 357ms/step - loss: 0.6051 - accuracy: 0.7101 - val_loss: 0.5893 - val_accuracy: 0.7241

# %% [markdown]
# **MODEL KETIGA**

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, AveragePooling2D, Dropout, Dense, Flatten
from tensorflow.keras.models import Model, Sequential

# %%
# Kita load model VGG16, kemudian kita potong bagian Top atau Fully Connected Layernya
baseModel = VGG16(include_top=False, input_tensor=Input(input_shape))

# %%
class FCHeadNet:
  def build(baseModel, classes, D):
    headModel = baseModel.output
    headModel = Flatten(name="flatten")(headModel)
    headModel = Dense(D, activation='elu')(headModel)
    headModel = Dropout(0.5)(headModel)
    headModel = Dense(classes, activation='sigmoid')(headModel)
    return headModel

headModel = FCHeadNet.build(baseModel, 1, 256)
model = Model(inputs=baseModel.input, outputs=headModel)

model.compile(optimizer=optimizer, 
              loss='binary_crossentropy', 
              metrics=['acc'])

model.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense_51 (Dense)            (None, 256)               2097408
#
#  dropout_22 (Dropout)        (None, 256)               0
#
#  dense_52 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 16,812,353
# Trainable params: 16,812,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 12/12 [==============================] - 5s 387ms/step - loss: 0.7232 - acc: 0.6667 - val_loss: 0.5912 - val_acc: 0.7241
# Epoch 22/40
# 12/12 [==============================] - 5s 392ms/step - loss: 0.6836 - acc: 0.6377 - val_loss: 0.5950 - val_acc: 0.7241
# Epoch 23/40
# 12/12 [==============================] - 5s 386ms/step - loss: 0.7677 - acc: 0.6522 - val_loss: 0.5948 - val_acc: 0.7241
# Epoch 24/40
# 12/12 [==============================] - 5s 390ms/step - loss: 0.6283 - acc: 0.6522 - val_loss: 0.5899 - val_acc: 0.7241
# Epoch 25/40
# 12/12 [==============================] - 5s 392ms/step - loss: 0.6526 - acc: 0.6957 - val_loss: 0.5905 - val_acc: 0.7241
# Epoch 26/40
# 12/12 [==============================] - 5s 395ms/step - loss: 0.7508 - acc: 0.6377 - val_loss: 0.5890 - val_acc: 0.7241
# Epoch 27/40
# 12/12 [==============================] - 5s 396ms/step - loss: 0.7034 - acc: 0.6232 - val_loss: 0.5945 - val_acc: 0.7241
# Epoch 28/40
# 12/12 [==============================] - 5s 389ms/step - loss: 0.6902 - acc: 0.6667 - val_loss: 0.5894 - val_acc: 0.7241
# Epoch 29/40
# 12/12 [==============================] - 5s 386ms/step - loss: 0.6552 - acc: 0.6667 - val_loss: 0.5890 - val_acc: 0.7241
# Epoch 30/40
# 12/12 [==============================] - 5s 392ms/step - loss: 0.7211 - acc: 0.6377 - val_loss: 0.5893 - val_acc: 0.7241
# Epoch 31/40
# 12/12 [==============================] - 5s 393ms/step - loss: 0.7056 - acc: 0.6087 - val_loss: 0.5895 - val_acc: 0.7241
# Epoch 32/40
# 12/12 [==============================] - 5s 401ms/step - loss: 0.7202 - acc: 0.6232 - val_loss: 0.5891 - val_acc: 0.7241
# Epoch 33/40
# 12/12 [==============================] - 5s 386ms/step - loss: 0.8511 - acc: 0.5072 - val_loss: 0.5921 - val_acc: 0.7241
# Epoch 34/40
# 12/12 [==============================] - 5s 390ms/step - loss: 0.6645 - acc: 0.6377 - val_loss: 0.5906 - val_acc: 0.7241
# Epoch 35/40
# 12/12 [==============================] - 5s 380ms/step - loss: 0.7666 - acc: 0.5797 - val_loss: 0.5892 - val_acc: 0.7241
# Epoch 36/40
# 12/12 [==============================] - 5s 392ms/step - loss: 0.6478 - acc: 0.6522 - val_loss: 0.5890 - val_acc: 0.7241
# Epoch 37/40
# 12/12 [==============================] - 5s 380ms/step - loss: 0.8083 - acc: 0.5942 - val_loss: 0.5972 - val_acc: 0.7241
# Epoch 38/40
# 12/12 [==============================] - 5s 390ms/step - loss: 0.8062 - acc: 0.5942 - val_loss: 0.5957 - val_acc: 0.7241
# Epoch 39/40
# 12/12 [==============================] - 6s 471ms/step - loss: 0.6595 - acc: 0.6522 - val_loss: 0.5918 - val_acc: 0.7241
# Epoch 40/40
# 12/12 [==============================] - 5s 386ms/step - loss: 0.7274 - acc: 0.6522 - val_loss: 0.5907 - val_acc: 0.7241

# %% [markdown]
# <br>
# <hr>
# <br>
#
#
# ### 4. Evaluation CNN
#
#
#
# <br>
# <br>

# %%
print("MODEL PERTAMA")
print("Accuracy Test -  ", model1.evaluate(validation_generator)[1]*100, '%')
print('-'*5)
print("MODEL KEDUA")
print("Accuracy Test -  ", model2.evaluate(validation_generator)[1]*100, '%')
print('-'*5)
print("MODEL KETIGA")
print("Accuracy Test -  ", model.evaluate(validation_generator)[1]*100, '%')
# Out:
# MODEL PERTAMA
# 5/5 [==============================] - 2s 391ms/step - loss: 0.3300 - accuracy: 0.8621
# Accuracy Test -   86.20689511299133 %
# -----
# MODEL KEDUA
# 5/5 [==============================] - 2s 388ms/step - loss: 0.5914 - accuracy: 0.7241
# Accuracy Test -   72.41379022598267 %
# -----
# MODEL KETIGA
# 5/5 [==============================] - 2s 377ms/step - loss: 0.5899 - acc: 0.7241
# Accuracy Test -   72.41379022598267 %

# %% [markdown]
# **PLOT MODEL PERTAMA**

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **PLOT MODEL KEDUA**

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **PLOT MODEL KETIGA**

# %%
plt.plot(history3.history['acc'])
plt.plot(history3.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **REPORT MODEL PERTAMA**

# %%
# true class
y_test = validation_generator.classes
# predict
y_pred = model1.predict(validation_generator)
y_pred = np.around(y_pred, decimals=0)
print(classification_report(y_test, y_pred, target_names=['Covid-19','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#     Covid-19       1.00      0.86      0.92        21
#       Normal       0.73      1.00      0.84         8
#
#     accuracy                           0.90        29
#    macro avg       0.86      0.93      0.88        29
# weighted avg       0.92      0.90      0.90        29

# %% [markdown]
# **REPORT MODEL KEDUA**

# %%
# true class
y_test = validation_generator.classes
# predict
y_pred = model2.predict(validation_generator)
y_pred = np.around(y_pred, decimals=0)
print(classification_report(y_test, y_pred, target_names=['Covid-19','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#     Covid-19       0.72      1.00      0.84        21
#       Normal       0.00      0.00      0.00         8
#
#     accuracy                           0.72        29
#    macro avg       0.36      0.50      0.42        29
# weighted avg       0.52      0.72      0.61        29

# %% [markdown]
# **REPORT MODEL KETIGA**

# %%
# true class
y_test = validation_generator.classes
# predict
y_pred = model.predict(validation_generator)
y_pred = np.around(y_pred, decimals=0)
print(classification_report(y_test, y_pred, target_names=['Covid-19','Normal']))
# Out:
#               precision    recall  f1-score   support
#
#     Covid-19       0.72      1.00      0.84        21
#       Normal       0.00      0.00      0.00         8
#
#     accuracy                           0.72        29
#    macro avg       0.36      0.50      0.42        29
# weighted avg       0.52      0.72      0.61        29

# %%
fig, axs = plt.subplots(5, 5, figsize=(12,12))
axs=axs.ravel()

for i in range(0,25):  
    axs[i].imshow(covid_images[i], cmap='gray')
    axs[i].set_title("Prediction Class = {} \n Original Class = {}".format(y_pred[i], y_test[i]))
    axs[i].axis('off')
plt.subplots_adjust(wspace=0.5)

# %% [markdown]
# <br>
# <br>
# <hr>
# <br>

# %% [markdown]
# ### Summary
# <br>
#
# The network at the end proved to be very unstable because it had few images, but after the data increase the convolutional network showed <b> 86% accuracy </b> in the test data with a Precision of <b> 95% </b> > what is a great result, but the detail is in the variance and instability that the model has.
#
# <br>
#
#
# The reason for I develop this project, was for apply techniques of Computer Vision with Data Augmentation and also experiment diverses layers as LayerNormalization, SpartialDropout2D and GlobalMaxPool2D.
#
# <br>
#
# This projetc allied with a doctor and health specialist, have big potential to be one Images Detector of Covid-19  apply a Healthcare.
#
# The biggest problem I encountered was the small dataset of images of x-rays classified with covid-19, only 70 images is very little for this problem
